# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('DataAnalyst.csv')

# %%
set(data['Salary Estimate'])
# Out:
# {'$110K-$190K (Glassdoor est.)',
#  '$113K-$132K (Glassdoor est.)',
#  '$24K-$48K (Glassdoor est.)',
#  '$26K-$47K (Glassdoor est.)',
#  '$27K-$52K (Glassdoor est.)',
#  '$28K-$52K (Glassdoor est.)',
#  '$29K-$38K (Glassdoor est.)',
#  '$30K-$53K (Glassdoor est.)',
#  '$30K-$54K (Glassdoor est.)',
#  '$31K-$59K (Glassdoor est.)',
#  '$32K-$56K (Glassdoor est.)',
#  '$34K-$61K (Glassdoor est.)',
#  '$35K-$42K (Glassdoor est.)',
#  '$35K-$45K (Glassdoor est.)',
#  '$35K-$67K (Glassdoor est.)',
#  '$36K-$67K (Glassdoor est.)',
#  '$37K-$44K (Glassdoor est.)',
#  '$37K-$66K (Glassdoor est.)',
#  '$37K-$68K (Glassdoor est.)',
#  '$37K-$70K (Glassdoor est.)',
#  '$38K-$68K (Glassdoor est.)',
#  '$40K-$72K (Glassdoor est.)',
#  '$40K-$74K (Glassdoor est.)',
#  '$41K-$78K (Glassdoor est.)',
#  '$41K-$86K (Glassdoor est.)',
#  '$42K-$63K (Glassdoor est.)',
#  '$42K-$66K (Glassdoor est.)',
#  '$42K-$74K (Glassdoor est.)',
#  '$42K-$76K (Glassdoor est.)',
#  '$43K-$69K (Glassdoor est.)',
# ...

# %%
maxlen = max(list(map(lambda x: len(x.split("-")) ,data['Salary Estimate'])))
cols = ["sal"+str(x)   for x in range(maxlen)]      
datalist = list(map(lambda x: x.split("-"), data['Salary Estimate'])) 
newdf = pd.DataFrame(data=datalist, columns=cols)   # create dataframe of new columns
newdf = pd.concat([data, newdf], axis=1)              # add it to original dataframe

# %%
newdf['sal1']=newdf['sal1'].str.replace(r'\D+', '').astype('int')
newdf['sal1']=newdf['sal1']*1000

# %%
newdf['sal0'].loc[newdf['sal0']=='']='0k'
newdf['sal0']=newdf['sal0'].str.replace(r'\D+', '').astype('int')
newdf['sal0']=newdf['sal0']*1000
# Out:
# c:\users\dell7559\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
newdf
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
newdf.describe()
# Out:
#        Unnamed: 0       Rating      Founded           sal0           sal1
# count   2253.0000  2253.000000  2253.000000    2253.000000    2253.000000
# mean    1126.0000     3.160630  1398.522858   54242.787395   89939.636041
# std      650.5294     1.665228   901.929251   19604.393281   29368.983761
# min        0.0000    -1.000000    -1.000000       0.000000    1000.000000
# 25%      563.0000     3.100000    -1.000000   41000.000000   70000.000000
# 50%     1126.0000     3.600000  1979.000000   50000.000000   87000.000000
# 75%     1689.0000     4.000000  2002.000000   64000.000000  104000.000000
# max     2252.0000     5.000000  2019.000000  113000.000000  190000.000000

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# ...

# %%
newdf.loc[newdf['Rating']==-1.0]
# Out:
#       Unnamed: 0                                          Job Title  \
# 11            11                                       Data Analyst
# 21            21                               Data Science Analyst
# 34            34                               Data Analyst (Games)
# 36            36                              Data Business Analyst
# 40            40                   Business Analyst, Data Platforms
# ...          ...                                                ...
# 2200        2200                                       Data Analyst
# 2202        2202                             Financial Data Analyst
# 2239        2239                       Senior Contract Data Analyst
# 2246        2246  Technical Business Analyst (SQL, Data analytic...
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
#
#                   Salary Estimate  \
# 11     $37K-$66K (Glassdoor est.)
# 21     $37K-$66K (Glassdoor est.)
# 34     $46K-$87K (Glassdoor est.)
# ...

# %%
newdf['salmed']=(newdf['sal0']+newdf['sal1'])/2

# %%
newdf
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
plt.hist(newdf['salmed'])
# Out:
# (array([  1.,   0., 278., 449., 665., 430., 231.,  88.,  54.,  57.]),
#  array([   500.,  15450.,  30400.,  45350.,  60300.,  75250.,  90200.,
#         105150., 120100., 135050., 150000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(newdf['salmed'],newdf['Size'],s=newdf['Rating'])
# Out:
# c:\users\dell7559\appdata\local\programs\python\python37\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
maxlen = max(list(map(lambda x: len(x.split("to")) ,newdf['Size'])))
cols = ["tam"+str(x)   for x in range(maxlen)]      
datalist = list(map(lambda x: x.split("to"), newdf['Size'])) 
dats = pd.DataFrame(data=datalist, columns=cols)   # create dataframe of new columns
dats = pd.concat([newdf, dats], axis=1)              # add it to original dataframe

# %%
dats['tam1']=dats['tam1'].fillna(dats['tam0'])

# %%
dats['tam0']=dats['tam0'].str.replace(r'Unknown', '-1')

# %%
set(dats['tam1'])
# Out:
# {' 1000 employees',
#  ' 10000 employees',
#  ' 200 employees',
#  ' 50 employees',
#  ' 500 employees',
#  ' 5000 employees',
#  '-1',
#  '10000+ employees',
#  'Unknown'}

# %%
dats['tam0']=dats['tam0'].str.replace(r'\D+', '').astype('int')

# %%
dats['tam1']=dats['tam1'].str.replace(r'Unknown', '-1')
dats['tam1']=dats['tam1'].str.replace(r'\D+', '').astype('int')

# %%
dats['tammed']=(dats['tam0']+dats['tam1'])/2

# %%
dats
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
dats.loc[dats['sal1']==1]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Headquarters, Size, Founded, Type of ownership, Industry, Sector, Revenue, Competitors, Easy Apply, sal0, sal1, salmed, tam0, tam1, tammed]
# Index: []
#
# [0 rows x 22 columns]

# %%
dats_train=
dats_test=

# %%
len(dats.groupby('Founded'))
# Out:
# 161

# %%
set(dats['sal1'])
# Out:
# {1000,
#  38000,
#  42000,
#  44000,
#  45000,
#  47000,
#  48000,
#  52000,
#  53000,
#  54000,
#  56000,
#  59000,
#  61000,
#  63000,
#  66000,
#  67000,
#  68000,
#  69000,
#  70000,
#  72000,
#  74000,
#  75000,
#  76000,
#  77000,
#  78000,
#  81000,
#  82000,
#  85000,
#  86000,
#  87000,
#  88000,
#  89000,
#  90000,
#  91000,
#  92000,
#  93000,
#  94000,
#  96000,
#  99000,
#  100000,
#  101000,
#  102000,
#  103000,
#  104000,
#  110000,
#  112000,
#  113000,
#  114000,
#  116000,
#  120000,
#  122000,
#  123000,
#  124000,
#  127000,
#  129000,
#  132000,
#  151000,
#  159000,
#  178000,
#  190000}

# %%
plt.figure(figsize=(15,15))
plt.hist(dats['Founded'].loc[dats['Founded']>2000])
# Out:
# (array([ 89.,  71.,  56., 111.,  17.,  76.,  64.,  59.,  40.,  23.]),
#  array([2001. , 2002.8, 2004.6, 2006.4, 2008.2, 2010. , 2011.8, 2013.6,
#         2015.4, 2017.2, 2019. ]),
#  <BarContainer object of 10 artists>)

# %%
df.groupby(["month","Status"]).count().Employee_No

# Plot
fig, ax = plt.subplots()
counts.plot(x=', y='f', kind='scatter', ax=ax)

# %%
grouped = dats.groupby(['Founded','Company Name']).size()
grouped
# Out:
# Founded  Company Name
# -1       1                                   1
#          1199SEIU Funds\n3.2                 2
#          1872 Consulting\n5.0                1
#          2000 east westmoreland st llc       1
#          212 Factors                         1
#                                             ..
#  2018    Strive Health\n5.0                  1
#          Vesta Healthcare                    1
#  2019    Fox Corporation\n4.0                1
#          National Education Partners\n4.6    2
#          Truist\n3.5                         1
# Length: 1514, dtype: int64
